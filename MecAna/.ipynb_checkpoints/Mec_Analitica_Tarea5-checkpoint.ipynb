# %%
from sympy import *
init_printing()

# %%
from sympy.physics.mechanics import dynamicsymbols, init_vprinting
init_vprinting()
t = Symbol('t')
theta , phi, psi = dynamicsymbols('theta phi psi')

# %%
I0, I3 = symbols('I_1 I_3')
phi, theta, psi, I0, I3
# Out:
# (φ, θ, ψ, I₁, I₃)

# %%
#Rotación alrededor de Z un ángulo phi.
Rphi = Matrix([[cos(phi), -sin(phi),0], [sin(phi), cos(phi), 0],[0,0,1]])
Rphi
# Out:
# ⎡cos(φ)  -sin(φ)  0⎤
# ⎢                  ⎥
# ⎢sin(φ)  cos(φ)   0⎥
# ⎢                  ⎥
# ⎣  0        0     1⎦

# %%
#Rotación alrededor de Z un ángulo psi.
Rpsi = Rphi.subs(phi,psi)
Rpsi
# Out:
# ⎡cos(ψ)  -sin(ψ)  0⎤
# ⎢                  ⎥
# ⎢sin(ψ)  cos(ψ)   0⎥
# ⎢                  ⎥
# ⎣  0        0     1⎦

# %%
#Rotación alrededor de X un ángulo theta.
Rtheta = Matrix([[1,0,0], [0, cos(theta), -sin(theta)], [0, sin(theta), cos(theta)]])
Rtheta
# Out:
# ⎡1    0        0   ⎤
# ⎢                  ⎥
# ⎢0  cos(θ)  -sin(θ)⎥
# ⎢                  ⎥
# ⎣0  sin(θ)  cos(θ) ⎦

# %%
#Rotación completa en términos de los ángulos de Euler.
R = simplify(Rphi * Rtheta * Rpsi)
R
# Out:
# ⎡-sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ)  -sin(φ)⋅cos(ψ)⋅cos(θ) - sin(ψ)⋅cos(φ)
# ⎢
# ⎢sin(φ)⋅cos(ψ) + sin(ψ)⋅cos(φ)⋅cos(θ)   -sin(φ)⋅sin(ψ) + cos(φ)⋅cos(ψ)⋅cos(θ)
# ⎢
# ⎣            sin(ψ)⋅sin(θ)                          sin(θ)⋅cos(ψ)
#
#  sin(φ)⋅sin(θ) ⎤
#                ⎥
#  -sin(θ)⋅cos(φ)⎥
#                ⎥
#      cos(θ)    ⎦

# %%
#Momento de inercia en el marco del cuerpo.
I = Matrix([[I0,0,0],[0,I0,0],[0,0,I3]])
I
# Out:
# ⎡I₁  0   0 ⎤
# ⎢          ⎥
# ⎢0   I₁  0 ⎥
# ⎢          ⎥
# ⎣0   0   I₃⎦

# %%
#Momento de inercia en el marco espacial.
Ie = simplify(R * I * R.T)
Ie
# Out:
# ⎡        2       2                 2       2
# ⎢- I₁⋅sin (φ)⋅sin (θ) + I₁ + I₃⋅sin (φ)⋅sin (θ)                     (I₁ - I₃)⋅
# ⎢
# ⎢
# ⎢                           2                          2       2            2
# ⎢       (I₁ - I₃)⋅sin(φ)⋅sin (θ)⋅cos(φ)          I₁⋅sin (φ)⋅sin (θ) - I₁⋅sin (
# ⎢
# ⎢
# ⎢   (-I₁ + I₃)⋅(cos(φ - 2⋅θ) - cos(φ + 2⋅θ))                    (I₁ - I₃)⋅(-si
# ⎢   ────────────────────────────────────────                    ──────────────
# ⎣                      4
#
#           2                                (-I₁ + I₃)⋅(cos(φ - 2⋅θ) - cos(φ +
# sin(φ)⋅sin (θ)⋅cos(φ)                      ───────────────────────────────────
#                                                               4
#
#                 2       2            2     (I₁ - I₃)⋅(-sin(φ - 2⋅θ) + sin(φ +
# θ) + I₁ - I₃⋅sin (φ)⋅sin (θ) + I₃⋅sin (θ)  ───────────────────────────────────
#                                                               4
#
# n(φ - 2⋅θ) + sin(φ + 2⋅θ))                             2            2
# ──────────────────────────                       I₁⋅sin (θ) - I₃⋅sin (θ) + I₃
#      4
#
# 2⋅θ))⎤
# ─────⎥
#      ⎥
#      ⎥
# 2⋅θ))⎥
# ─────⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎥
#      ⎦

# %%
#wx en su forma matricial. W = dR/dt * R^T
W = simplify(diff(R,t)*R.T)
W
# Out:
# ⎡             0                     -cos(θ)⋅ψ̇ - φ̇         sin(φ)⋅θ̇ - sin(θ)
# ⎢
# ⎢       cos(θ)⋅ψ̇ + φ̇                      0               -sin(φ)⋅sin(θ)⋅ψ̇
# ⎢
# ⎣-sin(φ)⋅θ̇ + sin(θ)⋅cos(φ)⋅ψ̇  sin(φ)⋅sin(θ)⋅ψ̇ + cos(φ)⋅θ̇               0
#
# ⋅cos(φ)⋅ψ̇ ⎤
#        ⎥
# - cos(φ)⋅θ̇⎥
#        ⎥
#            ⎦

# %%
#Vector w.
W[2,1],W[1,0], W[0,2]
# Out:
# (sin(φ)⋅sin(θ)⋅ψ̇ + cos(φ)⋅θ̇, cos(θ)⋅ψ̇ + φ̇, sin(φ)⋅θ̇ - sin(θ)⋅cos(φ)⋅ψ̇)

# %%
#Vector w a partir de los componentes de W. Esto es en la base espacial.
w = Matrix([W[2,1],W[0,2], W[1,0]])
w
# Out:
# ⎡sin(φ)⋅sin(θ)⋅ψ̇ + cos(φ)⋅θ̇⎤
# ⎢                          ⎥
# ⎢sin(φ)⋅θ̇ - sin(θ)⋅cos(φ)⋅ψ̇⎥
# ⎢                          ⎥
# ⎣       cos(θ)⋅ψ̇ + φ̇       ⎦

# %%
#w en la base del cuerpo.
w_c = simplify(R.T * w)
w_c
# Out:
# ⎡sin(ψ)⋅sin(θ)⋅φ̇ + cos(ψ)⋅θ̇ ⎤
# ⎢                           ⎥
# ⎢-sin(ψ)⋅θ̇ + sin(θ)⋅cos(ψ)⋅φ̇⎥
# ⎢                           ⎥
# ⎣       cos(θ)⋅φ̇ + ψ̇        ⎦

# %%
# w^T I w en la base espacial.
simplify(w.T*Ie*w)
# Out:
# ⎡      2     2       2         2     2                         2       2⎤
# ⎣I₁⋅sin (θ)⋅φ̇  + I₁⋅θ̇  - I₃⋅sin (θ)⋅φ̇  + 2⋅I₃⋅cos(θ)⋅φ̇⋅ψ̇ + I₃⋅φ̇  + I₃⋅ψ̇ ⎦

# %%
# w^T I w en la base fija al cuerpo. 
simplify( w_c.T*I*w_c )
# Out:
# ⎡      2     2       2         2     2                         2       2⎤
# ⎣I₁⋅sin (θ)⋅φ̇  + I₁⋅θ̇  - I₃⋅sin (θ)⋅φ̇  + 2⋅I₃⋅cos(θ)⋅φ̇⋅ψ̇ + I₃⋅φ̇  + I₃⋅ψ̇ ⎦

# %%
w_c.T*I*w_c
# Out:
# ⎡                                2                                  2
# ⎣I₁⋅(-sin(ψ)⋅θ̇ + sin(θ)⋅cos(ψ)⋅φ̇)  + I₁⋅(sin(ψ)⋅sin(θ)⋅φ̇ + cos(ψ)⋅θ̇)  + I₃
#
#            2⎤
# ⋅(cos(θ)⋅φ̇ + ψ̇) ⎦

# %%
#Punto 3 (no entregué este punto, solo el 1 y 2).
I1, I2, I3 = symbols('I_1 I_2 I_3')
w, w1, w2, w3 = dynamicsymbols('w w_1 w_2 w_3')
w = sqrt(w1**2 +w2**2+w3**2)
w
# Out:
#    _________________
#   ╱   2     2     2
# ╲╱  w₁  + w₂  + w₃

# %%
W = Matrix([[0,w3,-w2],[-w3,0,w1],[w2,-w1,0]])
W
# Out:
# ⎡ 0   w₃   -w₂⎤
# ⎢             ⎥
# ⎢-w₃   0   w₁ ⎥
# ⎢             ⎥
# ⎣w₂   -w₁   0 ⎦

# %%
W**2
# Out:
# ⎡    2     2                          ⎤
# ⎢- w₂  - w₃      w₁⋅w₂        w₁⋅w₃   ⎥
# ⎢                                     ⎥
# ⎢                 2     2             ⎥
# ⎢   w₁⋅w₂     - w₁  - w₃      w₂⋅w₃   ⎥
# ⎢                                     ⎥
# ⎢                              2     2⎥
# ⎣   w₁⋅w₃        w₂⋅w₃     - w₁  - w₂ ⎦

# %%
simplify(W**3)
# Out:
# ⎡                        ⎛  2     2     2⎞     ⎛  2     2     2⎞    ⎤
# ⎢          0            -⎝w₁  + w₂  + w₃ ⎠⋅w₃  ⎝w₁  + w₂  + w₃ ⎠⋅w₂ ⎥
# ⎢                                                                   ⎥
# ⎢⎛  2     2     2⎞                              ⎛  2     2     2⎞   ⎥
# ⎢⎝w₁  + w₂  + w₃ ⎠⋅w₃             0            -⎝w₁  + w₂  + w₃ ⎠⋅w₁⎥
# ⎢                                                                   ⎥
# ⎢ ⎛  2     2     2⎞     ⎛  2     2     2⎞                           ⎥
# ⎣-⎝w₁  + w₂  + w₃ ⎠⋅w₂  ⎝w₁  + w₂  + w₃ ⎠⋅w₁             0          ⎦

# %%
simplify(W**4)
# Out:
# ⎡           2
# ⎢⎛  2     2⎞      2   2     2   2       ⎛  2     2     2⎞                 ⎛  2
# ⎢⎝w₂  + w₃ ⎠  + w₁ ⋅w₂  + w₁ ⋅w₃       -⎝w₁  + w₂  + w₃ ⎠⋅w₁⋅w₂          -⎝w₁
# ⎢
# ⎢                                             2
# ⎢     ⎛  2     2     2⎞            ⎛  2     2⎞      2   2     2   2       ⎛  2
# ⎢    -⎝w₁  + w₂  + w₃ ⎠⋅w₁⋅w₂      ⎝w₁  + w₃ ⎠  + w₁ ⋅w₂  + w₂ ⋅w₃       -⎝w₁
# ⎢
# ⎢
# ⎢     ⎛  2     2     2⎞                 ⎛  2     2     2⎞            ⎛  2
# ⎣    -⎝w₁  + w₂  + w₃ ⎠⋅w₁⋅w₃          -⎝w₁  + w₂  + w₃ ⎠⋅w₂⋅w₃      ⎝w₁  + w₂
#
#                        ⎤
#      2     2⎞          ⎥
#  + w₂  + w₃ ⎠⋅w₁⋅w₃    ⎥
#                        ⎥
#                        ⎥
#      2     2⎞          ⎥
#  + w₂  + w₃ ⎠⋅w₂⋅w₃    ⎥
#                        ⎥
#   2                    ⎥
# 2⎞      2   2     2   2⎥
#  ⎠  + w₁ ⋅w₃  + w₂ ⋅w₃ ⎦

# %%
simplify(W**5)
# Out:
# ⎡                                                           ⎛  4       2   2
# ⎢                            0                              ⎝w₁  + 2⋅w₁ ⋅w₂  +
# ⎢
# ⎢ ⎛  4       2   2       2   2     4       2   2     4⎞
# ⎢-⎝w₁  + 2⋅w₁ ⋅w₂  + 2⋅w₁ ⋅w₃  + w₂  + 2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₃
# ⎢
# ⎢⎛  4       2   2       2   2     4       2   2     4⎞       ⎛  4       2   2
# ⎣⎝w₁  + 2⋅w₁ ⋅w₂  + 2⋅w₁ ⋅w₃  + w₂  + 2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₂   -⎝w₁  + 2⋅w₁ ⋅w₂
#
#      2   2     4       2   2     4⎞       ⎛  4       2   2       2   2     4
#  2⋅w₁ ⋅w₃  + w₂  + 2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₃   -⎝w₁  + 2⋅w₁ ⋅w₂  + 2⋅w₁ ⋅w₃  + w₂  +
#
#                                          ⎛  4       2   2       2   2     4
#           0                              ⎝w₁  + 2⋅w₁ ⋅w₂  + 2⋅w₁ ⋅w₃  + w₂  +
#
#       2   2     4       2   2     4⎞
# + 2⋅w₁ ⋅w₃  + w₂  + 2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₁                              0
#
#      2   2     4⎞   ⎤
#  2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₂⎥
#                     ⎥
#     2   2     4⎞    ⎥
# 2⋅w₂ ⋅w₃  + w₃ ⎠⋅w₁ ⎥
#                     ⎥
#                     ⎥
#                     ⎦

# %%
W**6
# Out:
# ⎡⎛  ⎛    2     2⎞           2⎞ ⎛⎛    2     2⎞        2   ⎞   ⎛⎛    2     2⎞
# ⎢⎝- ⎝- w₁  - w₂ ⎠⋅w₂ + w₂⋅w₃ ⎠⋅⎝⎝- w₂  - w₃ ⎠⋅w₂ - w₁ ⋅w₂⎠ + ⎝⎝- w₁  - w₃ ⎠⋅w₃
# ⎢
# ⎢                               ⎛⎛    2     2⎞           2⎞ ⎛⎛    2     2⎞
# ⎢                               ⎝⎝- w₁  - w₂ ⎠⋅w₁ - w₁⋅w₃ ⎠⋅⎝⎝- w₂  - w₃ ⎠⋅w₂
# ⎢
# ⎢                             ⎛  ⎛    2     2⎞           2⎞ ⎛  ⎛    2     2⎞
# ⎣                             ⎝- ⎝- w₁  - w₃ ⎠⋅w₁ + w₁⋅w₂ ⎠⋅⎝- ⎝- w₂  - w₃ ⎠⋅w
#
#      2   ⎞ ⎛  ⎛    2     2⎞        2   ⎞                               ⎛  ⎛
#  - w₂ ⋅w₃⎠⋅⎝- ⎝- w₂  - w₃ ⎠⋅w₃ + w₁ ⋅w₃⎠                               ⎝- ⎝- w
#
#     2   ⎞                                 ⎛⎛    2     2⎞           2⎞ ⎛  ⎛
# - w₁ ⋅w₂⎠                                 ⎝⎝- w₁  - w₂ ⎠⋅w₁ - w₁⋅w₃ ⎠⋅⎝- ⎝- w₁
#
#       2   ⎞                                                              ⎛⎛
# ₃ + w₁ ⋅w₃⎠                                                              ⎝⎝- w
#
#  2     2⎞           2⎞ ⎛  ⎛    2     2⎞           2⎞
# ₁  - w₂ ⎠⋅w₂ + w₂⋅w₃ ⎠⋅⎝- ⎝- w₁  - w₃ ⎠⋅w₁ + w₁⋅w₂ ⎠
#
# 2     2⎞           2⎞   ⎛⎛    2     2⎞        2   ⎞ ⎛  ⎛    2     2⎞        2
#   - w₃ ⎠⋅w₁ + w₁⋅w₂ ⎠ + ⎝⎝- w₁  - w₃ ⎠⋅w₃ - w₂ ⋅w₃⎠⋅⎝- ⎝- w₂  - w₃ ⎠⋅w₃ + w₁ ⋅
#
#  2     2⎞        2   ⎞ ⎛⎛    2     2⎞        2   ⎞
# ₁  - w₃ ⎠⋅w₃ - w₂ ⋅w₃⎠⋅⎝⎝- w₂  - w₃ ⎠⋅w₂ - w₁ ⋅w₂⎠
#
#                                     ⎛⎛    2     2⎞           2⎞ ⎛⎛    2     2⎞
#                                     ⎝⎝- w₁  - w₂ ⎠⋅w₁ - w₁⋅w₃ ⎠⋅⎝⎝- w₁  - w₃ ⎠
#
#   ⎞                               ⎛  ⎛    2     2⎞           2⎞ ⎛  ⎛    2
# w₃⎠                               ⎝- ⎝- w₁  - w₂ ⎠⋅w₂ + w₂⋅w₃ ⎠⋅⎝- ⎝- w₂  - w₃
#
#      ⎛⎛    2     2⎞           2⎞ ⎛  ⎛    2     2⎞           2⎞   ⎛  ⎛    2
#      ⎝⎝- w₁  - w₂ ⎠⋅w₁ - w₁⋅w₃ ⎠⋅⎝- ⎝- w₁  - w₃ ⎠⋅w₁ + w₁⋅w₂ ⎠ + ⎝- ⎝- w₁  - w
#
#         2   ⎞                               ⎤
# ⋅w₃ - w₂ ⋅w₃⎠                               ⎥
#                                             ⎥
# 2⎞        2   ⎞                             ⎥
#  ⎠⋅w₃ + w₁ ⋅w₃⎠                             ⎥
#                                             ⎥
#  2⎞           2⎞ ⎛⎛    2     2⎞        2   ⎞⎥
# ₂ ⎠⋅w₂ + w₂⋅w₃ ⎠⋅⎝⎝- w₂  - w₃ ⎠⋅w₂ - w₁ ⋅w₂⎠⎦

# %%
gamma, B, i = symbols('gamma B_0 I')
gamma, B, i
# Out:
# (γ, B₀, I)

# %%
L = simplify(i*(w.T*w)[0]/2) + i*gamma*B*w[2]
L
# Out:
#                           ⎛                2    2    2⎞
#                         I⋅⎝2⋅cos(θ)⋅φ̇⋅ψ̇ + φ̇  + ψ̇  + θ̇ ⎠
# B₀⋅I⋅γ⋅(cos(θ)⋅ψ̇ + φ̇) + ───────────────────────────────
#                                        2

# %%
Ppsi = simplify(diff(L,diff(psi))) #Pyt
Ppsi
# Out:
# I⋅(B₀⋅γ⋅cos(θ) + cos(θ)⋅φ̇ + ψ̇)

# %%
Pphi= simplify(diff(L,diff(phi)))
Pphi
# Out:
# I⋅(B₀⋅γ + cos(θ)⋅ψ̇ + φ̇)

# %%
Psi, Phi = symbols('P_psi P_phi')
Psi, Phi
# Out:
# (Pₚₛᵢ, Pᵩ)

# %%
S = linsolve([Psi-Ppsi, Phi-Pphi], (diff(phi), diff(psi)))
S.args[0][0]
# Out:
#             2
# - B₀⋅I⋅γ⋅sin (θ) + Pᵩ - Pₚₛᵢ⋅cos(θ)
# ───────────────────────────────────
#                   2
#              I⋅sin (θ)

# %%
a,b,c = symbols('\dot{\phi}, \dot{b}, \dot{\psi}')
c
# Out:
# \dot{\psi}

# %%
newL = L.subs(diff(phi),a).subs(diff(psi),c)
simplify(newL.subs(a,S.args[0][0]).subs(c,S.args[0][1]))
# Out:
#                           2                  3                              2
#     2  2  2    2  2     Pᵩ      2⋅Pᵩ⋅Pₚₛᵢ⋅cos (θ)   2⋅Pᵩ⋅Pₚₛᵢ⋅cos(θ)    Pₚₛᵢ
# - B₀ ⋅I ⋅γ  + I ⋅θ̇  + ─────── + ───────────────── - ──────────────── + ───────
#                          2              4                  4              2
#                       sin (θ)        sin (θ)            sin (θ)        sin (θ)
# ──────────────────────────────────────────────────────────────────────────────
#                                      2⋅I

# %%
i
# Out:
# I

# %%
simplify(Matrix([[1,cos(theta)],[cos(theta),1]]).inv())
# Out:
# ⎡   1      -cos(θ) ⎤
# ⎢───────   ────────⎥
# ⎢   2         2    ⎥
# ⎢sin (θ)   sin (θ) ⎥
# ⎢                  ⎥
# ⎢-cos(θ)      1    ⎥
# ⎢────────  ─────── ⎥
# ⎢   2         2    ⎥
# ⎣sin (θ)   sin (θ) ⎦

# %%
w0 , lamb= Symbol('w_0 lambda') 
w0
# Out:
# w₀

# %%
Rearth = Matrix([[1,0,0], [0, cos(w0*t), -sin(w0*t)], [0, sin(w0*t), cos(w0*t)]])
Rearth
# Out:
# ⎡1      0          0     ⎤
# ⎢                        ⎥
# ⎢0  cos(t⋅w₀)  -sin(t⋅w₀)⎥
# ⎢                        ⎥
# ⎣0  sin(t⋅w₀)  cos(t⋅w₀) ⎦

# %%
Rlat = Matrix([[cos(pi/2-theta),0,sin(pi/2-theta)],[0,1,0],[-sin(pi/2-theta),0,cos(pi/2-theta)]])
Rlat
# Out:
# ⎡sin(θ)   0  cos(θ)⎤
# ⎢                  ⎥
# ⎢   0     1    0   ⎥
# ⎢                  ⎥
# ⎣-cos(θ)  0  sin(θ)⎦

# %%
simplify(diff(Rearth*Rlat,t)*( Rearth*Rlat).T)
# Out:
# ⎡     0        sin(t⋅w₀)⋅θ̇  -cos(t⋅w₀)⋅θ̇⎤
# ⎢                                       ⎥
# ⎢-sin(t⋅w₀)⋅θ̇       0           -w₀     ⎥
# ⎢                                       ⎥
# ⎣cos(t⋅w₀)⋅θ̇       w₀            0      ⎦

# %%
dRearth =
